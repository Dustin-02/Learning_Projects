# %% [markdown]
# ## Vase Problem

# %%
from abc import ABCMeta, abstractmethod
import queue as Q
import numpy as np
# Basic data structure Stack
#
#
class Stack:
     def __init__(self):
         self.items = []
     def isEmpty(self):
         return self.items == []
     def push(self, item):
         self.items.append(item)
     def pop(self):
         return self.items.pop()
     def peek(self):
         return self.items[len(self.items)-1]
     def size(self):
         return len(self.items)
#
# Basic data structure Queue
# (Use my own Queue instead of import) 
#        
class Queue:
    def __init__(self):
        self.items = []
    def isEmpty(self):
        return self.items == []
    def add(self, item):
        self.items.insert(0,item)
    def get(self):
        return self.items.pop()
    def size(self):
        return len(self.items)
    
class Solver(metaclass=ABCMeta):
    """
     ABC=Abstract base class
     Abstract Solver class that searches through the state space, called by the Board class
    """
    @abstractmethod
    def get(self):
         raise NotImplementedError()
    @abstractmethod
    def add(self):
         raise NotImplementedError()
     
class Solver1(Solver):
    """
     Concrete solver: must implement abstract methods from abstract class Solver
     uses a Queue
    """
    def __init__(self):
        self.queue=Queue()
    def get(self):
        return self.queue.get()
    def add(self,board):
        self.queue.add(board)

class Solver2(Solver):
    """
     Concrete solver: must implement abstract methods from abstract class Solver
     Uses a Stack
    """
    def __init__(self):
        self.stack=Stack()
    def get(self):
        return self.stack.pop()
    def add(self,board):
        self.stack.push(board)

class Solver3:
    def __init__(self):
        self.pq = Q.PriorityQueue()
        self.goal = np.array([0, 8, 8, 8])

    def get(self):
        if not self.pq.empty():
            (val, board) = self.pq.get()
            return np.array(board), val
        return None, None

    def add(self, board):
        value = self.heuristic(board)
        self.pq.put((value, board.tolist()))

    def heuristic(self, board):
       return abs(8 - board[1]) + abs(8 - board[2]) + abs(8 - board[3])

# %% [markdown]
# ### Build the Board

# %%
class Board:
    def __init__(self):
        self.total_balsam = 24
        self.vessels = [5, 11, 13]
        self.board = np.array([24, 0, 0, 0])  # Initial state: [Remaining, Vessel1, Vessel2, Vessel3]
        self.goal = np.array([0, 8, 8, 8])  # Goal state
        self.used = []
        self.solver = Solver3()

    def solve(self):
        self.used = []
        self.solver.add(self.board)
        board, heuristic_value = self.solver.get()
        step = 0
        max_steps = 1000

        print("Vase Problem Solution Process:")
        print("==============================")

        while board is not None and step < max_steps:
            step += 1
            
            print(f"\nStep {step}:")
            print(f"Exploring State: {board}")
            self.printBoard(board)
            print(f"Heuristic Value: {heuristic_value}")
            
            if np.array_equal(board, self.goal):
                print("\n==============================")
                print("Solution found!")
                print(f"Total steps: {step}")
                return
            
            moves = self.getMoves(board)
            print("Valid Moves:")
            for i, move in enumerate(moves):
                from_vessel = "Remaining" if move[0] == 0 else f"Vessel {move[0]}"
                to_vessel = "Remaining" if move[1] == 0 else f"Vessel {move[1]}"
                print(f"  {i+1}. From {from_vessel} to {to_vessel}: {move[2]} oz")
            
            new_states_added = 0
            for move in moves:
                new_board = self.makeMove(board, move)
                if self.isNotUsed(new_board):
                    self.solver.add(new_board)
                    self.used.append(new_board)
                    new_states_added += 1
            
            print(f"New states added: {new_states_added}")
            
            board, heuristic_value = self.solver.get()
        
        print("\n==============================")
        if step >= max_steps:
            print(f"Search terminated after {max_steps} steps without finding a solution.")
        else:
            print("No solution found.")

    def getMoves(self, board):
        moves = []
        remaining, v1, v2, v3 = board
        
        # Pour from remaining to each vessel
        for i, capacity in enumerate(self.vessels):
            amount = min(remaining, capacity - board[i+1])
            if amount > 0:
                moves.append((0, i+1, amount))
        
        # Pour from each vessel to another or back to remaining
        for i in range(1, 4):
            for j in range(4):
                if i != j:
                    amount = min(board[i], self.vessels[j-1] - board[j]) if j != 0 else board[i]
                    if amount > 0:
                        moves.append((i, j, amount))
        
        return moves

    def makeMove(self, board, move):
        new_board = board.copy()
        from_vessel, to_vessel, amount = move
        new_board[from_vessel] -= amount
        new_board[to_vessel] += amount
        return new_board

    def isValidMove(self, board, move):
        from_vessel, to_vessel, amount = move
        if from_vessel == 0:
            return board[0] >= amount and self.vessels[to_vessel-1] - board[to_vessel] >= amount
        else:
            return board[from_vessel] >= amount and (to_vessel == 0 or self.vessels[to_vessel-1] - board[to_vessel] >= amount)

    def isNotUsed(self, board):
        return all(not np.array_equal(board, u) for u in self.used)

    def printBoard(self, board):
        print(f"Remaining: {board[0]} | Vessel 1 (5oz): {board[1]} | Vessel 2 (11oz): {board[2]} | Vessel 3 (13oz): {board[3]}")

# %% [markdown]
# ### Run and Test

# %%
def main():
    game = Board()
    game.solve()

if __name__ == '__main__':
    main()
# Out:
# Vase Problem Solution Process:
# ==============================
#
# Step 1:
# Exploring State: [24  0  0  0]
# Remaining: 24 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 0 | Vessel 3 (13oz): 0
# Heuristic Value: 32
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 11 oz
#   3. From Remaining to Vessel 3: 13 oz
# New states added: 3
#
# Step 2:
# Exploring State: [13  0 11  0]
# Remaining: 13 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 0
# Heuristic Value: 23
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 3: 13 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 2 to Vessel 3: 11 oz
# New states added: 5
#
# Step 3:
# Exploring State: [ 0  0 11 13]
# Remaining: 0 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 13
# Heuristic Value: 16
# Valid Moves:
#   1. From Vessel 2 to Remaining: 11 oz
#   2. From Vessel 2 to Vessel 1: 5 oz
#   3. From Vessel 3 to Remaining: 13 oz
#   4. From Vessel 3 to Vessel 1: 5 oz
# New states added: 2
#
# Step 4:
# Exploring State: [ 0  5 11  8]
# Remaining: 0 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 8
# Heuristic Value: 6
# Valid Moves:
#   1. From Vessel 1 to Remaining: 5 oz
#   2. From Vessel 1 to Vessel 3: 5 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 3: 5 oz
#   5. From Vessel 3 to Remaining: 8 oz
# New states added: 2
#
# Step 5:
# Exploring State: [ 0  5  6 13]
# Remaining: 0 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 13
# Heuristic Value: 10
# Valid Moves:
#   1. From Vessel 1 to Remaining: 5 oz
#   2. From Vessel 1 to Vessel 2: 5 oz
#   3. From Vessel 2 to Remaining: 6 oz
#   4. From Vessel 3 to Remaining: 13 oz
#   5. From Vessel 3 to Vessel 2: 5 oz
# New states added: 2
#
# Step 6:
# Exploring State: [ 5  0 11  8]
# Remaining: 5 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 8
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 2 to Vessel 3: 5 oz
#   6. From Vessel 3 to Remaining: 8 oz
#   7. From Vessel 3 to Vessel 1: 5 oz
# New states added: 3
#
# Step 7:
# Exploring State: [5 5 6 8]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 8
# Heuristic Value: 6
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 2
#
# Step 8:
# Exploring State: [ 5  5 11  3]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 3
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 3: 5 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 11 oz
#   5. From Vessel 2 to Vessel 3: 10 oz
#   6. From Vessel 3 to Remaining: 3 oz
# New states added: 2
#
# Step 9:
# Exploring State: [10  0  6  8]
# Remaining: 10 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 8
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 5 oz
#   3. From Remaining to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 6 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 5 oz
#   7. From Vessel 3 to Remaining: 8 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 4
#
# Step 10:
# Exploring State: [10  5  1  8]
# Remaining: 10 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 1 | Vessel 3 (13oz): 8
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 2: 10 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 1 oz
#   7. From Vessel 2 to Vessel 3: 1 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 8 oz
# New states added: 4
#
# Step 11:
# Exploring State: [10  5  6  3]
# Remaining: 10 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 3
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 10 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 6 oz
#   8. From Vessel 3 to Remaining: 3 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 1
#
# Step 12:
# Exploring State: [11  5  0  8]
# Remaining: 11 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 0 | Vessel 3 (13oz): 8
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 2: 11 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 3 to Remaining: 8 oz
#   7. From Vessel 3 to Vessel 2: 8 oz
# New states added: 2
#
# Step 13:
# Exploring State: [11  0  5  8]
# Remaining: 11 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 5 | Vessel 3 (13oz): 8
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 6 oz
#   3. From Remaining to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 5 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 5 oz
#   7. From Vessel 3 to Remaining: 8 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 6 oz
# New states added: 5
#
# Step 14:
# Exploring State: [6 5 5 8]
# Remaining: 6 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 5 | Vessel 3 (13oz): 8
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 2: 6 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 5 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 6 oz
# New states added: 4
#
# Step 15:
# Exploring State: [ 1  5  5 13]
# Remaining: 1 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 5 | Vessel 3 (13oz): 13
# Heuristic Value: 11
# Valid Moves:
#   1. From Remaining to Vessel 2: 1 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 2: 5 oz
#   4. From Vessel 2 to Remaining: 5 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 2: 6 oz
# New states added: 2
#
# Step 16:
# Exploring State: [ 1  5 11  7]
# Remaining: 1 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 7
# Heuristic Value: 7
# Valid Moves:
#   1. From Remaining to Vessel 3: 1 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 11 oz
#   5. From Vessel 2 to Vessel 3: 6 oz
#   6. From Vessel 3 to Remaining: 7 oz
# New states added: 3
#
# Step 17:
# Exploring State: [ 6  0 10  8]
# Remaining: 6 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 10 | Vessel 3 (13oz): 8
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 1 oz
#   3. From Remaining to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 10 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 5 oz
#   7. From Vessel 3 to Remaining: 8 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 1 oz
# New states added: 3
#
# Step 18:
# Exploring State: [ 1  5 10  8]
# Remaining: 1 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 10 | Vessel 3 (13oz): 8
# Heuristic Value: 5
# Valid Moves:
#   1. From Remaining to Vessel 2: 1 oz
#   2. From Remaining to Vessel 3: 1 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 1 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 10 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 1 oz
# New states added: 3
#
# Step 19:
# Exploring State: [ 0  5 10  9]
# Remaining: 0 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 10 | Vessel 3 (13oz): 9
# Heuristic Value: 6
# Valid Moves:
#   1. From Vessel 1 to Remaining: 5 oz
#   2. From Vessel 1 to Vessel 2: 1 oz
#   3. From Vessel 1 to Vessel 3: 4 oz
#   4. From Vessel 2 to Remaining: 10 oz
#   5. From Vessel 2 to Vessel 3: 4 oz
#   6. From Vessel 3 to Remaining: 9 oz
#   7. From Vessel 3 to Vessel 2: 1 oz
# New states added: 3
#
# Step 20:
# Exploring State: [ 1  4 11  8]
# Remaining: 1 | Vessel 1 (5oz): 4 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 8
# Heuristic Value: 7
# Valid Moves:
#   1. From Remaining to Vessel 1: 1 oz
#   2. From Remaining to Vessel 3: 1 oz
#   3. From Vessel 1 to Remaining: 4 oz
#   4. From Vessel 1 to Vessel 3: 4 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 1 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 1: 1 oz
# New states added: 3
#
# Step 21:
# Exploring State: [ 0  4 11  9]
# Remaining: 0 | Vessel 1 (5oz): 4 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 9
# Heuristic Value: 8
# Valid Moves:
#   1. From Vessel 1 to Remaining: 4 oz
#   2. From Vessel 1 to Vessel 3: 4 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 1 oz
#   5. From Vessel 2 to Vessel 3: 4 oz
#   6. From Vessel 3 to Remaining: 9 oz
#   7. From Vessel 3 to Vessel 1: 1 oz
# New states added: 3
#
# Step 22:
# Exploring State: [ 0  4  7 13]
# Remaining: 0 | Vessel 1 (5oz): 4 | Vessel 2 (11oz): 7 | Vessel 3 (13oz): 13
# Heuristic Value: 10
# Valid Moves:
#   1. From Vessel 1 to Remaining: 4 oz
#   2. From Vessel 1 to Vessel 2: 4 oz
#   3. From Vessel 2 to Remaining: 7 oz
#   4. From Vessel 2 to Vessel 1: 1 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 1: 1 oz
#   7. From Vessel 3 to Vessel 2: 4 oz
# New states added: 4
#
# Step 23:
# Exploring State: [ 0  5  7 12]
# Remaining: 0 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 7 | Vessel 3 (13oz): 12
# Heuristic Value: 8
# Valid Moves:
#   1. From Vessel 1 to Remaining: 5 oz
#   2. From Vessel 1 to Vessel 2: 4 oz
#   3. From Vessel 1 to Vessel 3: 1 oz
#   4. From Vessel 2 to Remaining: 7 oz
#   5. From Vessel 2 to Vessel 3: 1 oz
#   6. From Vessel 3 to Remaining: 12 oz
#   7. From Vessel 3 to Vessel 2: 4 oz
# New states added: 4
#
# Step 24:
# Exploring State: [ 1  4  6 13]
# Remaining: 1 | Vessel 1 (5oz): 4 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 13
# Heuristic Value: 11
# Valid Moves:
#   1. From Remaining to Vessel 1: 1 oz
#   2. From Remaining to Vessel 2: 1 oz
#   3. From Vessel 1 to Remaining: 4 oz
#   4. From Vessel 1 to Vessel 2: 4 oz
#   5. From Vessel 2 to Remaining: 6 oz
#   6. From Vessel 2 to Vessel 1: 1 oz
#   7. From Vessel 3 to Remaining: 13 oz
#   8. From Vessel 3 to Vessel 1: 1 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 2
#
# Step 25:
# Exploring State: [ 1  5  6 12]
# Remaining: 1 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 12
# Heuristic Value: 9
# Valid Moves:
#   1. From Remaining to Vessel 2: 1 oz
#   2. From Remaining to Vessel 3: 1 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 1 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 1 oz
#   8. From Vessel 3 to Remaining: 12 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 1
#
# Step 26:
# Exploring State: [ 5  0 10  9]
# Remaining: 5 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 10 | Vessel 3 (13oz): 9
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 1 oz
#   3. From Remaining to Vessel 3: 4 oz
#   4. From Vessel 2 to Remaining: 10 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 4 oz
#   7. From Vessel 3 to Remaining: 9 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 1 oz
# New states added: 3
#
# Step 27:
# Exploring State: [5 5 5 9]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 5 | Vessel 3 (13oz): 9
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 4 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 4 oz
#   6. From Vessel 2 to Remaining: 5 oz
#   7. From Vessel 2 to Vessel 3: 4 oz
#   8. From Vessel 3 to Remaining: 9 oz
#   9. From Vessel 3 to Vessel 2: 6 oz
# New states added: 2
#
# Step 28:
# Exploring State: [ 5  5 10  4]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 10 | Vessel 3 (13oz): 4
# Heuristic Value: 10
# Valid Moves:
#   1. From Remaining to Vessel 2: 1 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 1 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 10 oz
#   7. From Vessel 2 to Vessel 3: 9 oz
#   8. From Vessel 3 to Remaining: 4 oz
#   9. From Vessel 3 to Vessel 2: 1 oz
# New states added: 4
#
# Step 29:
# Exploring State: [ 4  5 11  4]
# Remaining: 4 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 4
# Heuristic Value: 11
# Valid Moves:
#   1. From Remaining to Vessel 3: 4 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 11 oz
#   5. From Vessel 2 to Vessel 3: 9 oz
#   6. From Vessel 3 to Remaining: 4 oz
# New states added: 2
#
# Step 30:
# Exploring State: [ 5  4 11  4]
# Remaining: 5 | Vessel 1 (5oz): 4 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 4
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 1 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 4 oz
#   4. From Vessel 1 to Vessel 3: 4 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 1 oz
#   7. From Vessel 2 to Vessel 3: 9 oz
#   8. From Vessel 3 to Remaining: 4 oz
#   9. From Vessel 3 to Vessel 1: 1 oz
# New states added: 2
#
# Step 31:
# Exploring State: [ 6  5 10  3]
# Remaining: 6 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 10 | Vessel 3 (13oz): 3
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 2: 1 oz
#   2. From Remaining to Vessel 3: 6 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 1 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 10 oz
#   7. From Vessel 2 to Vessel 3: 10 oz
#   8. From Vessel 3 to Remaining: 3 oz
#   9. From Vessel 3 to Vessel 2: 1 oz
# New states added: 2
#
# Step 32:
# Exploring State: [ 4  0 11  9]
# Remaining: 4 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 9
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 1: 4 oz
#   2. From Remaining to Vessel 3: 4 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 2 to Vessel 3: 4 oz
#   6. From Vessel 3 to Remaining: 9 oz
#   7. From Vessel 3 to Vessel 1: 5 oz
# New states added: 1
#
# Step 33:
# Exploring State: [4 5 6 9]
# Remaining: 4 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 9
# Heuristic Value: 7
# Valid Moves:
#   1. From Remaining to Vessel 2: 4 oz
#   2. From Remaining to Vessel 3: 4 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 4 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 4 oz
#   8. From Vessel 3 to Remaining: 9 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 2
#
# Step 34:
# Exploring State: [ 0  1 10 13]
# Remaining: 0 | Vessel 1 (5oz): 1 | Vessel 2 (11oz): 10 | Vessel 3 (13oz): 13
# Heuristic Value: 14
# Valid Moves:
#   1. From Vessel 1 to Remaining: 1 oz
#   2. From Vessel 1 to Vessel 2: 1 oz
#   3. From Vessel 2 to Remaining: 10 oz
#   4. From Vessel 2 to Vessel 1: 4 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 1: 4 oz
#   7. From Vessel 3 to Vessel 2: 1 oz
# New states added: 2
#
# Step 35:
# Exploring State: [ 0  1 11 12]
# Remaining: 0 | Vessel 1 (5oz): 1 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 12
# Heuristic Value: 14
# Valid Moves:
#   1. From Vessel 1 to Remaining: 1 oz
#   2. From Vessel 1 to Vessel 3: 1 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 4 oz
#   5. From Vessel 2 to Vessel 3: 1 oz
#   6. From Vessel 3 to Remaining: 12 oz
#   7. From Vessel 3 to Vessel 1: 4 oz
# New states added: 2
#
# Step 36:
# Exploring State: [ 5  0  7 12]
# Remaining: 5 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 7 | Vessel 3 (13oz): 12
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 4 oz
#   3. From Remaining to Vessel 3: 1 oz
#   4. From Vessel 2 to Remaining: 7 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 1 oz
#   7. From Vessel 3 to Remaining: 12 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 4 oz
# New states added: 4
#
# Step 37:
# Exploring State: [5 5 7 7]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 7 | Vessel 3 (13oz): 7
# Heuristic Value: 6
# Valid Moves:
#   1. From Remaining to Vessel 2: 4 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 4 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 7 oz
#   7. From Vessel 2 to Vessel 3: 6 oz
#   8. From Vessel 3 to Remaining: 7 oz
#   9. From Vessel 3 to Vessel 2: 4 oz
# New states added: 2
#
# Step 38:
# Exploring State: [ 5  1 11  7]
# Remaining: 5 | Vessel 1 (5oz): 1 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 7
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 4 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 1 oz
#   4. From Vessel 1 to Vessel 3: 1 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 4 oz
#   7. From Vessel 2 to Vessel 3: 6 oz
#   8. From Vessel 3 to Remaining: 7 oz
#   9. From Vessel 3 to Vessel 1: 4 oz
# New states added: 1
#
# Step 39:
# Exploring State: [10  0  7  7]
# Remaining: 10 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 7 | Vessel 3 (13oz): 7
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 4 oz
#   3. From Remaining to Vessel 3: 6 oz
#   4. From Vessel 2 to Remaining: 7 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 6 oz
#   7. From Vessel 3 to Remaining: 7 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 4 oz
# New states added: 3
#
# Step 40:
# Exploring State: [10  5  2  7]
# Remaining: 10 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 2 | Vessel 3 (13oz): 7
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 2: 9 oz
#   2. From Remaining to Vessel 3: 6 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 2 oz
#   7. From Vessel 2 to Vessel 3: 2 oz
#   8. From Vessel 3 to Remaining: 7 oz
#   9. From Vessel 3 to Vessel 2: 7 oz
# New states added: 3
#
# Step 41:
# Exploring State: [10  5  7  2]
# Remaining: 10 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 7 | Vessel 3 (13oz): 2
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 2: 4 oz
#   2. From Remaining to Vessel 3: 10 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 4 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 7 oz
#   7. From Vessel 2 to Vessel 3: 7 oz
#   8. From Vessel 3 to Remaining: 2 oz
#   9. From Vessel 3 to Vessel 2: 2 oz
# New states added: 3
#
# Step 42:
# Exploring State: [ 5  5  2 12]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 2 | Vessel 3 (13oz): 12
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 1 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 1 oz
#   6. From Vessel 2 to Remaining: 2 oz
#   7. From Vessel 2 to Vessel 3: 1 oz
#   8. From Vessel 3 to Remaining: 12 oz
#   9. From Vessel 3 to Vessel 2: 9 oz
# New states added: 0
#
# Step 43:
# Exploring State: [ 6  0 11  7]
# Remaining: 6 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 7
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 3: 6 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 2 to Vessel 3: 6 oz
#   6. From Vessel 3 to Remaining: 7 oz
#   7. From Vessel 3 to Vessel 1: 5 oz
# New states added: 1
#
# Step 44:
# Exploring State: [6 5 6 7]
# Remaining: 6 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 7
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 6 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 6 oz
#   8. From Vessel 3 to Remaining: 7 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 1
#
# Step 45:
# Exploring State: [ 6  4 11  3]
# Remaining: 6 | Vessel 1 (5oz): 4 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 3
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 1 oz
#   2. From Remaining to Vessel 3: 6 oz
#   3. From Vessel 1 to Remaining: 4 oz
#   4. From Vessel 1 to Vessel 3: 4 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 1 oz
#   7. From Vessel 2 to Vessel 3: 10 oz
#   8. From Vessel 3 to Remaining: 3 oz
#   9. From Vessel 3 to Vessel 1: 1 oz
# New states added: 2
#
# Step 46:
# Exploring State: [ 6  5 11  2]
# Remaining: 6 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 2
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 3: 6 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 11 oz
#   5. From Vessel 2 to Vessel 3: 11 oz
#   6. From Vessel 3 to Remaining: 2 oz
# New states added: 0
#
# Step 47:
# Exploring State: [9 0 6 9]
# Remaining: 9 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 9
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 5 oz
#   3. From Remaining to Vessel 3: 4 oz
#   4. From Vessel 2 to Remaining: 6 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 4 oz
#   7. From Vessel 3 to Remaining: 9 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 3
#
# Step 48:
# Exploring State: [9 5 6 4]
# Remaining: 9 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 4
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 9 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 6 oz
#   8. From Vessel 3 to Remaining: 4 oz
#   9. From Vessel 3 to Vessel 2: 4 oz
# New states added: 2
#
# Step 49:
# Exploring State: [9 5 1 9]
# Remaining: 9 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 1 | Vessel 3 (13oz): 9
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 2: 9 oz
#   2. From Remaining to Vessel 3: 4 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 4 oz
#   6. From Vessel 2 to Remaining: 1 oz
#   7. From Vessel 2 to Vessel 3: 1 oz
#   8. From Vessel 3 to Remaining: 9 oz
#   9. From Vessel 3 to Vessel 2: 9 oz
# New states added: 2
#
# Step 50:
# Exploring State: [11  0  6  7]
# Remaining: 11 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 7
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 5 oz
#   3. From Remaining to Vessel 3: 6 oz
#   4. From Vessel 2 to Remaining: 6 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 6 oz
#   7. From Vessel 3 to Remaining: 7 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 2
#
# Step 51:
# Exploring State: [11  5  1  7]
# Remaining: 11 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 1 | Vessel 3 (13oz): 7
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 2: 10 oz
#   2. From Remaining to Vessel 3: 6 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 1 oz
#   7. From Vessel 2 to Vessel 3: 1 oz
#   8. From Vessel 3 to Remaining: 7 oz
#   9. From Vessel 3 to Vessel 2: 7 oz
# New states added: 2
#
# Step 52:
# Exploring State: [11  5  5  3]
# Remaining: 11 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 5 | Vessel 3 (13oz): 3
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 2: 6 oz
#   2. From Remaining to Vessel 3: 10 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 5 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 3 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 1
#
# Step 53:
# Exploring State: [11  5  6  2]
# Remaining: 11 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 2
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 11 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 6 oz
#   8. From Vessel 3 to Remaining: 2 oz
#   9. From Vessel 3 to Vessel 2: 2 oz
# New states added: 1
#
# Step 54:
# Exploring State: [11  5  8  0]
# Remaining: 11 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 0
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 2: 3 oz
#   2. From Remaining to Vessel 3: 11 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 3 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 8 oz
#   7. From Vessel 2 to Vessel 3: 8 oz
# New states added: 4
#
# Step 55:
# Exploring State: [ 0  5  8 11]
# Remaining: 0 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 11
# Heuristic Value: 6
# Valid Moves:
#   1. From Vessel 1 to Remaining: 5 oz
#   2. From Vessel 1 to Vessel 2: 3 oz
#   3. From Vessel 1 to Vessel 3: 2 oz
#   4. From Vessel 2 to Remaining: 8 oz
#   5. From Vessel 2 to Vessel 3: 2 oz
#   6. From Vessel 3 to Remaining: 11 oz
#   7. From Vessel 3 to Vessel 2: 3 oz
# New states added: 4
#
# Step 56:
# Exploring State: [ 0  3  8 13]
# Remaining: 0 | Vessel 1 (5oz): 3 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 13
# Heuristic Value: 10
# Valid Moves:
#   1. From Vessel 1 to Remaining: 3 oz
#   2. From Vessel 1 to Vessel 2: 3 oz
#   3. From Vessel 2 to Remaining: 8 oz
#   4. From Vessel 2 to Vessel 1: 2 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 1: 2 oz
#   7. From Vessel 3 to Vessel 2: 3 oz
# New states added: 4
#
# Step 57:
# Exploring State: [ 0  3 11 10]
# Remaining: 0 | Vessel 1 (5oz): 3 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 10
# Heuristic Value: 10
# Valid Moves:
#   1. From Vessel 1 to Remaining: 3 oz
#   2. From Vessel 1 to Vessel 3: 3 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 2 oz
#   5. From Vessel 2 to Vessel 3: 3 oz
#   6. From Vessel 3 to Remaining: 10 oz
#   7. From Vessel 3 to Vessel 1: 2 oz
# New states added: 4
#
# Step 58:
# Exploring State: [ 0  5  9 10]
# Remaining: 0 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 10
# Heuristic Value: 6
# Valid Moves:
#   1. From Vessel 1 to Remaining: 5 oz
#   2. From Vessel 1 to Vessel 2: 2 oz
#   3. From Vessel 1 to Vessel 3: 3 oz
#   4. From Vessel 2 to Remaining: 9 oz
#   5. From Vessel 2 to Vessel 3: 3 oz
#   6. From Vessel 3 to Remaining: 10 oz
#   7. From Vessel 3 to Vessel 2: 2 oz
# New states added: 2
#
# Step 59:
# Exploring State: [ 0  2  9 13]
# Remaining: 0 | Vessel 1 (5oz): 2 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 13
# Heuristic Value: 12
# Valid Moves:
#   1. From Vessel 1 to Remaining: 2 oz
#   2. From Vessel 1 to Vessel 2: 2 oz
#   3. From Vessel 2 to Remaining: 9 oz
#   4. From Vessel 2 to Vessel 1: 3 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 1: 3 oz
#   7. From Vessel 3 to Vessel 2: 2 oz
# New states added: 3
#
# Step 60:
# Exploring State: [ 0  2 11 11]
# Remaining: 0 | Vessel 1 (5oz): 2 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 11
# Heuristic Value: 12
# Valid Moves:
#   1. From Vessel 1 to Remaining: 2 oz
#   2. From Vessel 1 to Vessel 3: 2 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 3 oz
#   5. From Vessel 2 to Vessel 3: 2 oz
#   6. From Vessel 3 to Remaining: 11 oz
#   7. From Vessel 3 to Vessel 1: 3 oz
# New states added: 2
#
# Step 61:
# Exploring State: [ 5  0  8 11]
# Remaining: 5 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 11
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 3 oz
#   3. From Remaining to Vessel 3: 2 oz
#   4. From Vessel 2 to Remaining: 8 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 2 oz
#   7. From Vessel 3 to Remaining: 11 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 2
#
# Step 62:
# Exploring State: [5 5 8 6]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 6
# Heuristic Value: 6
# Valid Moves:
#   1. From Remaining to Vessel 2: 3 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 3 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 8 oz
#   7. From Vessel 2 to Vessel 3: 7 oz
#   8. From Vessel 3 to Remaining: 6 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 4
#
# Step 63:
# Exploring State: [ 2  5 11  6]
# Remaining: 2 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 6
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 3: 2 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 11 oz
#   5. From Vessel 2 to Vessel 3: 7 oz
#   6. From Vessel 3 to Remaining: 6 oz
# New states added: 2
#
# Step 64:
# Exploring State: [ 2  5  4 13]
# Remaining: 2 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 4 | Vessel 3 (13oz): 13
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 2: 2 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 2: 5 oz
#   4. From Vessel 2 to Remaining: 4 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 2: 7 oz
# New states added: 2
#
# Step 65:
# Exploring State: [ 5  0  9 10]
# Remaining: 5 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 10
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 2 oz
#   3. From Remaining to Vessel 3: 3 oz
#   4. From Vessel 2 to Remaining: 9 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 3 oz
#   7. From Vessel 3 to Remaining: 10 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 2 oz
# New states added: 4
#
# Step 66:
# Exploring State: [5 5 9 5]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 5
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 2: 2 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 2 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 9 oz
#   7. From Vessel 2 to Vessel 3: 8 oz
#   8. From Vessel 3 to Remaining: 5 oz
#   9. From Vessel 3 to Vessel 2: 2 oz
# New states added: 4
#
# Step 67:
# Exploring State: [ 3  5 11  5]
# Remaining: 3 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 5
# Heuristic Value: 10
# Valid Moves:
#   1. From Remaining to Vessel 3: 3 oz
#   2. From Vessel 1 to Remaining: 5 oz
#   3. From Vessel 1 to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 11 oz
#   5. From Vessel 2 to Vessel 3: 8 oz
#   6. From Vessel 3 to Remaining: 5 oz
# New states added: 2
#
# Step 68:
# Exploring State: [ 5  5  4 10]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 4 | Vessel 3 (13oz): 10
# Heuristic Value: 10
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 3 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 3 oz
#   6. From Vessel 2 to Remaining: 4 oz
#   7. From Vessel 2 to Vessel 3: 3 oz
#   8. From Vessel 3 to Remaining: 10 oz
#   9. From Vessel 3 to Vessel 2: 7 oz
# New states added: 2
#
# Step 69:
# Exploring State: [ 5  2 11  6]
# Remaining: 5 | Vessel 1 (5oz): 2 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 6
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 3 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 2 oz
#   4. From Vessel 1 to Vessel 3: 2 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 3 oz
#   7. From Vessel 2 to Vessel 3: 7 oz
#   8. From Vessel 3 to Remaining: 6 oz
#   9. From Vessel 3 to Vessel 1: 3 oz
# New states added: 1
#
# Step 70:
# Exploring State: [ 5  3 11  5]
# Remaining: 5 | Vessel 1 (5oz): 3 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 5
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 2 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 3 oz
#   4. From Vessel 1 to Vessel 3: 3 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 2 oz
#   7. From Vessel 2 to Vessel 3: 8 oz
#   8. From Vessel 3 to Remaining: 5 oz
#   9. From Vessel 3 to Vessel 1: 2 oz
# New states added: 2
#
# Step 71:
# Exploring State: [ 5  5  3 11]
# Remaining: 5 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 3 | Vessel 3 (13oz): 11
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 2: 5 oz
#   2. From Remaining to Vessel 3: 2 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 2 oz
#   6. From Vessel 2 to Remaining: 3 oz
#   7. From Vessel 2 to Vessel 3: 2 oz
#   8. From Vessel 3 to Remaining: 11 oz
#   9. From Vessel 3 to Vessel 2: 8 oz
# New states added: 2
#
# Step 72:
# Exploring State: [10  0  8  6]
# Remaining: 10 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 6
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 3 oz
#   3. From Remaining to Vessel 3: 7 oz
#   4. From Vessel 2 to Remaining: 8 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 7 oz
#   7. From Vessel 3 to Remaining: 6 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 3
#
# Step 73:
# Exploring State: [10  5  3  6]
# Remaining: 10 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 3 | Vessel 3 (13oz): 6
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 2: 8 oz
#   2. From Remaining to Vessel 3: 7 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 3 oz
#   7. From Vessel 2 to Vessel 3: 3 oz
#   8. From Vessel 3 to Remaining: 6 oz
#   9. From Vessel 3 to Vessel 2: 6 oz
# New states added: 1
#
# Step 74:
# Exploring State: [10  5  8  1]
# Remaining: 10 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 1
# Heuristic Value: 13
# Valid Moves:
#   1. From Remaining to Vessel 2: 3 oz
#   2. From Remaining to Vessel 3: 10 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 3 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 8 oz
#   7. From Vessel 2 to Vessel 3: 8 oz
#   8. From Vessel 3 to Remaining: 1 oz
#   9. From Vessel 3 to Vessel 2: 1 oz
# New states added: 4
#
# Step 75:
# Exploring State: [ 2  0  9 13]
# Remaining: 2 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 13
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 2 oz
#   2. From Remaining to Vessel 2: 2 oz
#   3. From Vessel 2 to Remaining: 9 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 1: 5 oz
#   7. From Vessel 3 to Vessel 2: 2 oz
# New states added: 1
#
# Step 76:
# Exploring State: [2 5 9 8]
# Remaining: 2 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 8
# Heuristic Value: 4
# Valid Moves:
#   1. From Remaining to Vessel 2: 2 oz
#   2. From Remaining to Vessel 3: 2 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 2 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 9 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 2 oz
# New states added: 2
#
# Step 77:
# Exploring State: [ 2  3 11  8]
# Remaining: 2 | Vessel 1 (5oz): 3 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 8
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 1: 2 oz
#   2. From Remaining to Vessel 3: 2 oz
#   3. From Vessel 1 to Remaining: 3 oz
#   4. From Vessel 1 to Vessel 3: 3 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 2 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 1: 2 oz
# New states added: 2
#
# Step 78:
# Exploring State: [7 0 9 8]
# Remaining: 7 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 8
# Heuristic Value: 11
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 2 oz
#   3. From Remaining to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 9 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 5 oz
#   7. From Vessel 3 to Remaining: 8 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 2 oz
# New states added: 2
#
# Step 79:
# Exploring State: [7 5 4 8]
# Remaining: 7 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 4 | Vessel 3 (13oz): 8
# Heuristic Value: 9
# Valid Moves:
#   1. From Remaining to Vessel 2: 7 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 4 oz
#   7. From Vessel 2 to Vessel 3: 4 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 7 oz
# New states added: 1
#
# Step 80:
# Exploring State: [7 5 9 3]
# Remaining: 7 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 9 | Vessel 3 (13oz): 3
# Heuristic Value: 11
# Valid Moves:
#   1. From Remaining to Vessel 2: 2 oz
#   2. From Remaining to Vessel 3: 7 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 2 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 9 oz
#   7. From Vessel 2 to Vessel 3: 9 oz
#   8. From Vessel 3 to Remaining: 3 oz
#   9. From Vessel 3 to Vessel 2: 2 oz
# New states added: 2
#
# Step 81:
# Exploring State: [ 2  3  6 13]
# Remaining: 2 | Vessel 1 (5oz): 3 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 13
# Heuristic Value: 12
# Valid Moves:
#   1. From Remaining to Vessel 1: 2 oz
#   2. From Remaining to Vessel 2: 2 oz
#   3. From Vessel 1 to Remaining: 3 oz
#   4. From Vessel 1 to Vessel 2: 3 oz
#   5. From Vessel 2 to Remaining: 6 oz
#   6. From Vessel 2 to Vessel 1: 2 oz
#   7. From Vessel 3 to Remaining: 13 oz
#   8. From Vessel 3 to Vessel 1: 2 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 2
#
# Step 82:
# Exploring State: [ 2  5  6 11]
# Remaining: 2 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 11
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 2: 2 oz
#   2. From Remaining to Vessel 3: 2 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 2 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 2 oz
#   8. From Vessel 3 to Remaining: 11 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
# New states added: 1
#
# Step 83:
# Exploring State: [ 2  0 11 11]
# Remaining: 2 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 11
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 2 oz
#   2. From Remaining to Vessel 3: 2 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 2 to Vessel 3: 2 oz
#   6. From Vessel 3 to Remaining: 11 oz
#   7. From Vessel 3 to Vessel 1: 5 oz
# New states added: 0
#
# Step 84:
# Exploring State: [ 3  0  8 13]
# Remaining: 3 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 13
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 3 oz
#   2. From Remaining to Vessel 2: 3 oz
#   3. From Vessel 2 to Remaining: 8 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 3 to Remaining: 13 oz
#   6. From Vessel 3 to Vessel 1: 5 oz
#   7. From Vessel 3 to Vessel 2: 3 oz
# New states added: 1
#
# Step 85:
# Exploring State: [3 5 8 8]
# Remaining: 3 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 8
# Heuristic Value: 4
# Valid Moves:
#   1. From Remaining to Vessel 2: 3 oz
#   2. From Remaining to Vessel 3: 3 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 3 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 8 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 2
#
# Step 86:
# Exploring State: [ 3  2 11  8]
# Remaining: 3 | Vessel 1 (5oz): 2 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 8
# Heuristic Value: 10
# Valid Moves:
#   1. From Remaining to Vessel 1: 3 oz
#   2. From Remaining to Vessel 3: 3 oz
#   3. From Vessel 1 to Remaining: 2 oz
#   4. From Vessel 1 to Vessel 3: 2 oz
#   5. From Vessel 2 to Remaining: 11 oz
#   6. From Vessel 2 to Vessel 1: 3 oz
#   7. From Vessel 2 to Vessel 3: 5 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 1: 3 oz
# New states added: 2
#
# Step 87:
# Exploring State: [8 0 8 8]
# Remaining: 8 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 8
# Heuristic Value: 10
# Valid Moves:
#   1. From Remaining to Vessel 1: 5 oz
#   2. From Remaining to Vessel 2: 3 oz
#   3. From Remaining to Vessel 3: 5 oz
#   4. From Vessel 2 to Remaining: 8 oz
#   5. From Vessel 2 to Vessel 1: 5 oz
#   6. From Vessel 2 to Vessel 3: 5 oz
#   7. From Vessel 3 to Remaining: 8 oz
#   8. From Vessel 3 to Vessel 1: 5 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 3
#
# Step 88:
# Exploring State: [8 5 3 8]
# Remaining: 8 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 3 | Vessel 3 (13oz): 8
# Heuristic Value: 10
# Valid Moves:
#   1. From Remaining to Vessel 2: 8 oz
#   2. From Remaining to Vessel 3: 5 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 3 oz
#   7. From Vessel 2 to Vessel 3: 3 oz
#   8. From Vessel 3 to Remaining: 8 oz
#   9. From Vessel 3 to Vessel 2: 8 oz
# New states added: 1
#
# Step 89:
# Exploring State: [8 5 8 3]
# Remaining: 8 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 8 | Vessel 3 (13oz): 3
# Heuristic Value: 10
# Valid Moves:
#   1. From Remaining to Vessel 2: 3 oz
#   2. From Remaining to Vessel 3: 8 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 3 oz
#   5. From Vessel 1 to Vessel 3: 5 oz
#   6. From Vessel 2 to Remaining: 8 oz
#   7. From Vessel 2 to Vessel 3: 8 oz
#   8. From Vessel 3 to Remaining: 3 oz
#   9. From Vessel 3 to Vessel 2: 3 oz
# New states added: 2
#
# Step 90:
# Exploring State: [ 3  0 11 10]
# Remaining: 3 | Vessel 1 (5oz): 0 | Vessel 2 (11oz): 11 | Vessel 3 (13oz): 10
# Heuristic Value: 14
# Valid Moves:
#   1. From Remaining to Vessel 1: 3 oz
#   2. From Remaining to Vessel 3: 3 oz
#   3. From Vessel 2 to Remaining: 11 oz
#   4. From Vessel 2 to Vessel 1: 5 oz
#   5. From Vessel 2 to Vessel 3: 3 oz
#   6. From Vessel 3 to Remaining: 10 oz
#   7. From Vessel 3 to Vessel 1: 5 oz
# New states added: 1
#
# Step 91:
# Exploring State: [ 3  5  6 10]
# Remaining: 3 | Vessel 1 (5oz): 5 | Vessel 2 (11oz): 6 | Vessel 3 (13oz): 10
# Heuristic Value: 8
# Valid Moves:
#   1. From Remaining to Vessel 2: 3 oz
#   2. From Remaining to Vessel 3: 3 oz
#   3. From Vessel 1 to Remaining: 5 oz
#   4. From Vessel 1 to Vessel 2: 5 oz
#   5. From Vessel 1 to Vessel 3: 3 oz
#   6. From Vessel 2 to Remaining: 6 oz
#   7. From Vessel 2 to Vessel 3: 3 oz
#   8. From Vessel 3 to Remaining: 10 oz
#   9. From Vessel 3 to Vessel 2: 5 oz
